# %%
# Import Dependencies
import pandas as pd
import json

from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
from config import password

# %%
csv = 'Resources/COBRA-2021.csv'

# %%
crime_data = pd.read_csv(csv)

# %%
crime_data.head()
# Out:
#    offense_id   rpt_date occur_date  occur_day  occur_day_num occur_time  \
# 0    21140096  5/20/2021  5/19/2021  Wednesday            4.0      15:20
# 1    21791668  6/28/2021  6/27/2021     Sunday            1.0      21:17
# 2   200041082   1/5/2021   1/4/2021     Monday            2.0      16:00
# 3   202611428  9/18/2021  9/18/2021   Saturday            7.0      18:04
# 4   202771329  8/19/2021  10/3/2020   Saturday            7.0      16:29
#
#    poss_date poss_time  beat  zone  \
# 0  5/19/2021     15:25   103     1
# 1  6/28/2021     20:00   102     1
# 2   1/4/2021     17:00   605     6
# 3  9/18/2021     18:15   112     1
# 4  10/3/2020     16:29   109     1
#
#                                             location ibr_code  \
# 0  1720 MARIETTA BLVD NW\nATLANTA, GA 30318\nUNIT...      23F
# 1  870 MAYSON TURNER RD NW\nATLANTA, GA 30314\nUN...      23H
# 2  275 MEMORIAL DR SE\nATLANTA, GEORGIA 30312\nUN...      23C
# 3  2750 DONALD LEE HOLLOWELL PKWY NW\nATLANTA, GA...      23C
# 4  665 S GRAND AVE NW\nATLANTA, GA 30318\nUNITED ...      13A
#
#             UC2_Literal     neighborhood npu        lat       long
# 0  LARCENY-FROM VEHICLE       Hills Park   D  33.801693 -84.436453
# 1   LARCENY-NON VEHICLE        Vine City   L  33.755768 -84.416631
# 2   LARCENY-NON VEHICLE       Grant Park   W  33.746503 -84.378535
# 3   LARCENY-NON VEHICLE  Collier Heights   I  33.777383 -84.477433
# 4           AGG ASSAULT      Center Hill   J  33.773172 -84.462489

# %%
crime_data.dtypes
# Out:
# offense_id         int64
# rpt_date          object
# occur_date        object
# occur_day         object
# occur_day_num    float64
# occur_time        object
# poss_date         object
# poss_time         object
# beat               int64
# zone               int64
# location          object
# ibr_code          object
# UC2_Literal       object
# neighborhood      object
# npu               object
# lat              float64
# long             float64
# dtype: object

# %%
crime_data.count()
# Out:
# offense_id       21397
# rpt_date         21397
# occur_date       21385
# occur_day        21385
# occur_day_num    21385
# occur_time       21385
# poss_date        20994
# poss_time        20994
# beat             21397
# zone             21397
# location         21397
# ibr_code         21397
# UC2_Literal      21397
# neighborhood     20325
# npu              21094
# lat              21397
# long             21397
# dtype: int64

# %%
del crime_data['beat']

# %%
del crime_data['ibr_code']

# %%
del crime_data['poss_date']

# %%
del crime_data['poss_time']

# %%
del crime_data['rpt_date']

# %%
del crime_data['npu']

# %%
del crime_data['occur_day_num']

# %%
cleaned_df = crime_data.dropna()

# %%
cleaned_crime = cleaned_df.replace('\n',' ', regex=True)

# %%
cleaned_crime.reset_index(drop = True, inplace = True)

# %%
cleaned_crime_df = cleaned_crime.rename(columns={'UC2_Literal':'crime_type'})

# %%
cleaned_crime_df.head(30)
# Out:
#     offense_id  occur_date  occur_day occur_time  zone  \
# 0     21140096   5/19/2021  Wednesday      15:20     1
# 1     21791668   6/27/2021     Sunday      21:17     1
# 2    200041082    1/4/2021     Monday      16:00     6
# 3    202611428   9/18/2021   Saturday      18:04     1
# 4    202771329   10/3/2020   Saturday      16:29     1
# 19  3104 E SHADOWLAWN AVE NE ATLANTA, GA 30305 UNI...  LARCENY-FROM VEHICLE
# 20  1801 HOWELL MILL RD NW ATLANTA, GA 30318 UNITE...   LARCENY-NON VEHICLE
# 21  240 NORTH HIGHLAND AVENUE NORTHEAST ATLANTA, G...   LARCENY-NON VEHICLE
# 22     100 BELL ST SE ATLANTA, GA 30312 UNITED STATES   LARCENY-NON VEHICLE
# 23  2750 DONALD LEE HOLLOWELL PKWY NW ATLANTA, GA ...   LARCENY-NON VEHICLE
# 24  2321 COUNTY LINE RD SW ATLANTA, GA 30331 UNITE...   LARCENY-NON VEHICLE
# 25  3393 PEACHTREE RD ATLANTA, GA 30326 UNITED STATES   LARCENY-NON VEHICLE
# 26  1270 W PEACHTREE ST NW ATLANTA, GA 30309 UNITE...            AUTO THEFT
# 27  1270 W PEACHTREE ST NW ATLANTA, GA 30309 UNITE...  LARCENY-FROM VEHICLE
# 28      35 14TH ST NE ATLANTA, GA 30309 UNITED STATES            AUTO THEFT
# 29  3535 PEACHTREE RD NE ATLANTA, GA 30326 UNITED ...  LARCENY-FROM VEHICLE
#
#          neighborhood        lat       long
# 0          Hills Park  33.801693 -84.436453
# 1           Vine City  33.755768 -84.416631
# 2          Grant Park  33.746503 -84.378535
# 3     Collier Heights  33.777383 -84.477433
# 4         Center Hill  33.773172 -84.462489
# 5    Glenrose Heights  33.680124 -84.395728
# 6        Hunter Hills  33.760872 -84.426391
# 7           Vine City  33.755758 -84.413691
# 8        East Atlanta  33.730409 -84.336533
# 9     Buckhead Forest  33.846656 -84.376344
# 10    Bankhead/Bolton  33.787392 -84.494529
# 11           Downtown  33.770654 -84.389471
# 12            Midtown  33.780458 -84.388810
# 13          Southwest  33.704542 -84.468344
# 14           Downtown  33.764315 -84.388238
# 15        Peoplestown  33.730455 -84.387574
# 16   Campbellton Road  33.701046 -84.466460
# 17   Buckhead Heights  33.848247 -84.354648
# 18          Southwest  33.692468 -84.490825
# 19   Buckhead Village  33.839730 -84.374391
# 20      Berkeley Park  33.803280 -84.411933
# 21         Inman Park  33.762309 -84.360046
# 22       Sweet Auburn  33.751499 -84.378391
# 23    Collier Heights  33.777383 -84.477433
# 24  Arlington Estates  33.691754 -84.534809
# 25              Lenox  33.846726 -84.362420
# 26            Midtown  33.789380 -84.388232
# 27            Midtown  33.789380 -84.388232
# 28            Midtown  33.786219 -84.386389
# 29              Lenox  33.851566 -84.358703

# %%
cleaned_crime_df.count()
# Out:
# offense_id      20315
# occur_date      20315
# occur_day       20315
# occur_time      20315
# zone            20315
# location        20315
# crime_type      20315
# neighborhood    20315
# lat             20315
# long            20315
# dtype: int64

# %%
cleaned_crime_df.to_json("crime_data.json")

# %% [markdown]
# ## Export to Postgres

# %%
# Create engine to connect to database in PGadmin
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/atl_crime_db')

# Create the database if it does not already exist
if not database_exists(engine.url):
    create_database(engine.url)

print(database_exists(engine.url))
# Out:
# True

# %%
# Send the cleaned_crime_df to the atl_crime_db databse in PGadmin
cleaned_crime_df.to_sql('atl_crime2021', con=engine, if_exists = 'append', index = False)
